# %%
import os

# %%
path = ('/Users/zroper/Desktop/GitHub/TextParser')
pathex = path + '/'
os.chdir(path)

# %%
os.listdir()
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  'pivot_all_vars.xlsx',
#  'Raw_vars.txt',
#  'TextParser_workspace.ipynb',
#  '~$pivot_all_vars.xlsx']

# %%
fname = ('Raw_vars.txt')

# %%
with open(fname) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content]

# %%
content
# Out:
# ['a_sets@WATCHBOD =2 (0x00000002)',
#  'ABORT =65 (0x00000041)',
#  'Abort_ =2620 (0x00000A3C)',
#  'aCLEAR =3 (0x00000003)',
#  'adjacent@FLS_PGS =0.000000 (0x00000000)',
#  'adjacent@CMD_PGS =0.000000 (0x00000000)',
#  'adjacent@MG_PGS =0.000000 (0x00000000)',
#  'adjacent@GNG_PGS =0.000000 (0x00000000)',
#  'adjacent@DEL_PGS =0.000000 (0x00000000)',
#  'adjacent@TSCH_PGS =0.000000 (0x00000000)',
#  'adjacent@LSCH_PGS =0.000000 (0x00000000)',
#  'aFILLED =5 (0x00000005)',
#  'aINVISIBLE =4 (0x00000004)',
#  'Allowed_fix_time =0 (0x00000000)',
#  'allowed_fix_time@CMDTRIAL =0 (0x00000000)',
#  'allowed_fix_time@MGTRIAL =0 (0x00000000)',
#  'allowed_fix_time@SCHTRIAL =0 (0x00000000)',
#  'allowed_fix_time@GNGTRIAL =0 (0x00000000)',
#  'allowed_fix_time@DELTRIAL =0 (0x00000000)',
#  'allowed_fix_time@FIXTRIAL =0 (0x00000000)',
#  'AnalogUnits =65536.000000 (0x47800000)',
#  'analogUnits@WATCHEYE =0.000000 (0x00000000)',
#  'Angle =0.000000 (0x00000000)',
# ...

# %%
spline = ()
splines = ()

# %%
for line in content:
    spline,byproduct = line.split(' ',1)
    byproduct,junk = byproduct.split(' ',1)
    byproduct = byproduct[1:]
    print(spline,byproduct,junk)
# Out:
# a_sets@WATCHBOD 2 (0x00000002)
# ABORT 65 (0x00000041)
# Abort_ 2620 (0x00000A3C)
# aCLEAR 3 (0x00000003)
# adjacent@FLS_PGS 0.000000 (0x00000000)
# adjacent@CMD_PGS 0.000000 (0x00000000)
# adjacent@MG_PGS 0.000000 (0x00000000)
# adjacent@GNG_PGS 0.000000 (0x00000000)
# adjacent@DEL_PGS 0.000000 (0x00000000)
# adjacent@TSCH_PGS 0.000000 (0x00000000)
# adjacent@LSCH_PGS 0.000000 (0x00000000)
# aFILLED 5 (0x00000005)
# aINVISIBLE 4 (0x00000004)
# Allowed_fix_time 0 (0x00000000)
# allowed_fix_time@CMDTRIAL 0 (0x00000000)
# allowed_fix_time@MGTRIAL 0 (0x00000000)
# allowed_fix_time@SCHTRIAL 0 (0x00000000)
# allowed_fix_time@GNGTRIAL 0 (0x00000000)
# allowed_fix_time@DELTRIAL 0 (0x00000000)
# allowed_fix_time@FIXTRIAL 0 (0x00000000)
# AnalogUnits 65536.000000 (0x47800000)
# analogUnits@WATCHEYE 0.000000 (0x00000000)
# Angle 0.000000 (0x00000000)
# angle@WINDOWS 0.000000 (0x00000000)
# angle@DRW_T 0.000000 (0x00000000)
# angle@DRW_L 0.000000 (0x00000000)
# ...

# %%
for line in content:
    spline,byproduct = line.split(' ',1)
    if '@' in spline: 
        spline,junk = spline.split('@',1)
    else:
        junk = 'ORIGIN.PRO'
    print(junk+'@)
# Out:
#   File "<ipython-input-13-07737564ef0e>", line 7
#     print(junk+'@)
#                   ^
# SyntaxError: EOL while scanning string literal
